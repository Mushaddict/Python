# %%
import numpy as np
import matplotlib.pyplot as plt
n1 = plt.imread("flower.jpg")
plt.imshow(n1)
# n1为三维数组，最高维是图像的高，次高维是图像的宽，最低维[R, G, B]是颜色值
n2 = np.array([0.299, 0.587, 0.114]) # 灰度公式的固定值
x = np.dot(n1, n2)
plt.imshow(x, cmap = 'gray')
plt.show()
